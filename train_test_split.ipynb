# %% [markdown]
# # Data splitting technique to fit any Machine Learning Model

# %%
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
data = pd.read_csv("north_korea_missile_test_database.csv")

# %%
data.head()
# Out:
#    F1      Date Date Entered/Updated Launch Time (UTC) Missile Name  \
# 0   1  9-Apr-84            23-Dec-16               NaN       Scud-B
# 1   2  9-Apr-84            23-Dec-16               NaN       Scud-B
# 2   3  9-Apr-84            23-Dec-16               NaN       Scud-B
# 3   4    Sep-84            23-Dec-16               NaN       Scud-B
# 4   5    Sep-84            23-Dec-16               NaN       Scud-B
#
#   Missile Type Launch Agency/Authority                       Facility Name  \
# 0         SRBM                     NaN  Tonghae Satellite Launching Ground
# 1         SRBM                     NaN  Tonghae Satellite Launching Ground
# 2         SRBM                     NaN  Tonghae Satellite Launching Ground
# 3         SRBM                     NaN  Tonghae Satellite Launching Ground
# 4         SRBM                     NaN  Tonghae Satellite Launching Ground
#
#                         Facility Location  Other Name Facility Latitude  \
# ...

# %%
y = data["Missile Name"]

# %%
x = data.drop("Missile Name",axis=1)

# %%
y
# Out:
# 0            Scud-B
# 1            Scud-B
# 2            Scud-B
# 3            Scud-B
# 4            Scud-B
#            ...
# 130           KN-25
# 131           KN-25
# 132           KN-25
# 133           KN-25
# 134    Pukguksong-3
# Name: Missile Name, Length: 135, dtype: object

# %%
x
# Out:
#       F1       Date Date Entered/Updated Launch Time (UTC) Missile Type  \
# 0      1   9-Apr-84            23-Dec-16               NaN         SRBM
# 1      2   9-Apr-84            23-Dec-16               NaN         SRBM
# 2      3   9-Apr-84            23-Dec-16               NaN         SRBM
# 3      4     Sep-84            23-Dec-16               NaN         SRBM
# 4      5     Sep-84            23-Dec-16               NaN         SRBM
# ..   ...        ...                  ...               ...          ...
# 130  132  23-Aug-19            11-Sep-19       10:02:00 PM         SRBM
# 131  133   9-Sep-19            11-Sep-19       09:53:00 PM         SRBM
# 132  134   9-Sep-19            11-Sep-19       10:12:00 PM         SRBM
# 133  135   9-Sep-19            11-Sep-19               NaN         SRBM
# 134  136   1-Oct-19            04-Oct-19       10:00:00 PM         SLBM
#
#     Launch Agency/Authority                       Facility Name  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=30)

# %%
x_train.shape
# Out:
# (94, 18)

# %%
y_train.shape
# Out:
# (94,)

# %%
x_test.shape
# Out:
# (41, 18)

# %%
y_test.shape
# Out:
# (41,)
